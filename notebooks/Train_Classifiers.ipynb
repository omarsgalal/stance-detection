# %%
# !gdown --folder 1TJMndsdyWv5sviPoHcVghoqD4FK9Qpk6 >> log.txt

# %%
# !pip install datasets >> log.txt

# %%
import numpy as np
import os
SEED = 12345

# %%
from datasets import load_dataset
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# load dataset
dataset = load_dataset("NoraAlt/Mawqif_Stance-Detection")

# convert to pandas dataframe
df = pd.DataFrame({k: dataset['train'][k] for k, _ in dataset['train'].features.items()})
df['stance'] = df['stance'].apply(lambda x: "Neutral" if x is None else x)

# train test split
train_df, test_df = train_test_split(df, test_size=500, random_state=12345)

# print sizes
print(f"train length: {len(train_df)}")
print(f"test length: {len(test_df)}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/2.38k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.40M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/3502 [00:00<?, ? examples/s]
# train length: 3002
# test length: 500

# %%
# prompt: convert train_df stance to another column that is integers

stance_to_int = {
  "Against": 0,
  "Favor": 1,
  "Neutral": 2
}
int_to_stance = {value: key for key, value in stance_to_int.items()}

train_df['stance_int'] = train_df['stance'].map(stance_to_int)
test_df['stance_int'] = test_df['stance'].map(stance_to_int)

# %%
embeddings = {}
for file_name in os.listdir("embeddings"):
    if "train" in file_name and file_name.endswith(".npy"):
        base_name = file_name.split("_train")[0]
        train = f"{base_name}_train.npy"
        test = f"{base_name}_test.npy"
        embeddings[base_name] = {"train": np.load(os.path.join("embeddings", train)), "test": np.load(os.path.join("embeddings", test))}

# %%
from sklearn.metrics import f1_score, classification_report
def evaluate(test_df, y_pred):
    sum_f2_final = 0
    sum_f3_final = 0
    results = {}
    for target in test_df["target"].unique():
        target_indices = [i for i in range(len(test_df['target'].tolist())) if test_df['target'].tolist()[i] == target]
        filtered_test_labels = [test_df['stance_int'].tolist()[i] for i in target_indices]
        filtered_predictions = [y_pred[i] for i in target_indices]
        # print(classification_report(filtered_test_labels, filtered_predictions))
        f1_3class = f1_score(filtered_test_labels, filtered_predictions, average = None)
        sum_f2_final += (f1_3class[0] + f1_3class[1])/2
        sum_f3_final += sum(f1_3class)/3
        results[target] = {"F1_score_2class": (f1_3class[0] + f1_3class[1])/2, "F1_score_3class": sum(f1_3class)/3}
    results["All Targets"] = {"F1_score_2class": sum_f2_final/3, "F1_score_3class": sum_f3_final/3}
    return results

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
# Define your neural network model
class MLP_zero_layer(nn.Module):
    def __init__(self, input_size, output_size):
        super(MLP_zero_layer, self).__init__()
        self.fc1 = nn.Linear(input_size, output_size)

    def forward(self, x):
        x = self.fc1(x)
        return x

def pytorch_model_train_predict(model, X_train, y_train, X_test, num_epochs = 100, lr = 0.001):
    np.random.seed(SEED)
    torch.manual_seed(SEED)

    # Convert data to PyTorch tensors
    X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.long)
    X_test_tensor = torch.tensor(X_test, dtype=torch.float32)

    # Define your model, loss function, and optimizer
    input_size = X_train.shape[1]
    output_size = len(np.unique(y_train))  # number of unique classes
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)

    n_iter_no_change = 10
    tol = 1e-4
    best_loss = 100000000
    no_improvement = 0

    # Training loop
    num_epochs = num_epochs  # you can adjust this as needed
    for epoch in range(num_epochs):
        iter_loss = 0
        for i in range(0, len(X_train_tensor), 200):
            X_train_tensor_batch = X_train_tensor[i:i+200]
            y_train_tensor_batch = y_train_tensor[i:i+200]
            model.train()
            optimizer.zero_grad()
            outputs = model(X_train_tensor_batch)
            loss = criterion(outputs, y_train_tensor_batch)
            loss.backward()
            optimizer.step()
            iter_loss += float(loss)

        # Early stopping
        if iter_loss < best_loss - tol:
            best_loss = iter_loss
            no_improvement = 0
        else:
            no_improvement += 1
            if no_improvement >= n_iter_no_change:
                print(f'Early stopping at epoch {epoch} as there is no improvement in loss.')
                break

    # Evaluation
    model.eval()
    with torch.no_grad():
        y_pred_tensor = model(X_test_tensor)
        _, predicted = torch.max(y_pred_tensor, 1)
        y_pred = predicted.numpy()
    return model, y_pred

def pytorch_zero_model_train_predict(X_train, y_train, X_test, num_epochs = 100, lr = 0.001, hidden_layer_sizes = None):
    # Define your model, loss function, and optimizer
    input_size = X_train.shape[1]
    output_size = len(np.unique(y_train))  # number of unique classes
    model = MLP_zero_layer(input_size, output_size)
    return pytorch_model_train_predict(model, X_train, y_train, X_test, num_epochs, lr)



import torch
import torch.nn as nn

class MLP(nn.Module):
    def __init__(self, input_size, output_size, hidden_layers_sizes):
        super(MLP, self).__init__()
        self.input_size = input_size
        self.output_size = output_size
        self.hidden_layers_sizes = hidden_layers_sizes

        # Create the input layer
        self.input_layer = nn.Linear(input_size, hidden_layers_sizes[0])

        # Create the hidden layers
        self.hidden_layers = nn.ModuleList()
        for i in range(len(hidden_layers_sizes) - 1):
            self.hidden_layers.append(nn.Linear(hidden_layers_sizes[i], hidden_layers_sizes[i+1]))

        # Create the output layer
        self.output_layer = nn.Linear(hidden_layers_sizes[-1], output_size)

    def forward(self, x):
        # Forward pass through input layer
        x = torch.relu(self.input_layer(x))

        # Forward pass through hidden layers
        for hidden_layer in self.hidden_layers:
            x = torch.relu(hidden_layer(x))

        # Forward pass through output layer
        x = self.output_layer(x)
        return x

# # Example usage:
# input_size = 10
# output_size = 1
# hidden_layers_sizes = [20, 30, 20]

# mlp = MLP(input_size, output_size, hidden_layers_sizes)
# print(mlp)

def pytorch_hidden_layers_model_train_predict(X_train, y_train, X_test, num_epochs = 100, lr = 0.001, hidden_layer_sizes = [100]):
    # Define your model, loss function, and optimizer
    input_size = X_train.shape[1]
    output_size = len(np.unique(y_train))  # number of unique classes
    model = MLP(input_size, output_size, hidden_layer_sizes)
    return pytorch_model_train_predict(model, X_train, y_train, X_test, num_epochs, lr)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier

def sklearn_logreg_model_train_predict(X_train, y_train, X_test, num_epochs = 100, lr=None, hidden_layer_sizes = None):
    clf = LogisticRegression(
        random_state=SEED,
        max_iter=num_epochs,
    )

    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    return clf, y_pred

def sklearn_MLP_zero_model_train_predict(X_train, y_train, X_test, num_epochs = 100, lr = 0.001, hidden_layer_sizes = None):
    clf = MLPClassifier(
        hidden_layer_sizes=(),
        max_iter=num_epochs,
        random_state=SEED,
        learning_rate_init = lr
    )

    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    return clf, y_pred


def sklearn_MLP_hidden_layers_model_train_predict(X_train, y_train, X_test, num_epochs = 100, lr = 0.001, hidden_layer_sizes = [100]):
    clf = MLPClassifier(
        hidden_layer_sizes=hidden_layer_sizes,
        max_iter=num_epochs,
        random_state=SEED,
        learning_rate_init = lr
    )

    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    return clf, y_pred

# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from imbalanced-learn) (3.5.0)

# %%
from imblearn.over_sampling import SMOTE

# %%
train_df_no_index = train_df.reset_index()
train_df_cov = train_df_no_index[train_df_no_index["target"] == "Covid Vaccine"]
train_df_dig = train_df_no_index[train_df_no_index["target"] == "Digital Transformation"]
train_df_women = train_df_no_index[train_df_no_index["target"] == "Women empowerment"]

test_df_no_index = test_df.reset_index()
test_df_cov = test_df_no_index[test_df_no_index["target"] == "Covid Vaccine"]
test_df_dig = test_df_no_index[test_df_no_index["target"] == "Digital Transformation"]
test_df_women = test_df_no_index[test_df_no_index["target"] == "Women empowerment"]

def train_on_different_tagets(embed_model_name, name, func_name, X_train, X_test, num_epochs = 100, lr = 0.001, hidden_layer_sizes = None, do_smote = False):
    y_pred = np.zeros((len(X_test)))

    y_train = train_df_cov["stance_int"].tolist()
    train_embed_target = train_embed[train_df_cov.index]
    test_embed_target = test_embed[test_df_cov.index]
    if do_smote:
        train_embed_target, y_train = SMOTE().fit_resample(train_embed_target, y_train)
    model_cov, y_pred_target = func_name(train_embed_target, y_train, test_embed_target, num_epochs, lr, hidden_layer_sizes)
    y_pred[test_df_cov.index] = y_pred_target

    y_train = train_df_dig["stance_int"].tolist()
    train_embed_target = train_embed[train_df_dig.index]
    test_embed_target = test_embed[test_df_dig.index]
    if do_smote:
        train_embed_target, y_train = SMOTE().fit_resample(train_embed_target, y_train)
    model_dig, y_pred_target = func_name(train_embed_target, y_train, test_embed_target, num_epochs, lr, hidden_layer_sizes)
    y_pred[test_df_dig.index] = y_pred_target

    y_train = train_df_women["stance_int"].tolist()
    train_embed_target = train_embed[train_df_women.index]
    test_embed_target = test_embed[test_df_women.index]
    if do_smote:
        train_embed_target, y_train = SMOTE().fit_resample(train_embed_target, y_train)
    model_women, y_pred_target = func_name(train_embed_target, y_train, test_embed_target, num_epochs, lr, hidden_layer_sizes)
    y_pred[test_df_women.index] = y_pred_target

    results = evaluate(test_df, y_pred)
    if embed_model_name not in experiments:
        experiments[embed_model_name] = {}
    experiments[embed_model_name][name] = {"models": {"Digital Transformation": model_dig, "Covid Vaccine": model_cov, "Women empowerment": model_women}, "results": results, "score": results["All Targets"]["F1_score_2class"]}

# %%
train_df_cov.shape, train_df_dig.shape, train_df_women.shape
# Out:
# ((976, 16), (974, 16), (1052, 16))

# %%
experiments = {}

# !gdown "1Ve19rpQp6KLLc_w-GiJ-RPdZVY2IUOZ1"
# import pickle
# with open('experiments.pkl', 'rb') as f:
#     experiments = pickle.load(f)

# %%
# from tqdm.notebook import tqdm

# for embed_model_name in tqdm(embeddings.keys()):
#     train_embed = embeddings[embed_model_name]["train"]
#     test_embed = embeddings[embed_model_name]["test"]

#     train_on_different_tagets(embed_model_name, "pytorch_zero_hidden_epochs_100_lr_0.001_per_target", pytorch_zero_model_train_predict, train_embed, test_embed, num_epochs = 100)
#     train_on_different_tagets(embed_model_name, "sklearn_logreg_epochs_100_lr_0.001_per_target", sklearn_logreg_model_train_predict, train_embed, test_embed, num_epochs = 100)
#     train_on_different_tagets(embed_model_name, "sklearn_MLP_zero_hidden_epochs_100_lr_0.001_per_target", sklearn_MLP_zero_model_train_predict, train_embed, test_embed, num_epochs = 100)

from tqdm.notebook import tqdm


for embed_model_name in tqdm(embeddings.keys()):
    train_embed = embeddings[embed_model_name]["train"]
    test_embed = embeddings[embed_model_name]["test"]
    y_train = train_df["stance_int"].tolist()
    for num_epochs in [100, 1000]:
        for hidden_layer_sizes in [[100], [300], [300, 100], [300, 100, 10]]:
            train_on_different_tagets(embed_model_name, f"pytorch_with_hidden_epochs_{num_epochs}_lr_0.001_per_target_hidden_{'_'.join([str(h) for h in hidden_layer_sizes])}_per_target", pytorch_hidden_layers_model_train_predict, train_embed, test_embed, num_epochs = 100, hidden_layer_sizes = hidden_layer_sizes)
            train_on_different_tagets(embed_model_name, f"sklearn_MLP_with_hidden_epochs_{num_epochs}_lr_0.001_per_target_hidden_{'_'.join([str(h) for h in hidden_layer_sizes])}_per_target", sklearn_MLP_hidden_layers_model_train_predict, train_embed, test_embed, num_epochs = 100, hidden_layer_sizes = hidden_layer_sizes)

            model, y_pred = pytorch_hidden_layers_model_train_predict(train_embed, y_train, test_embed, num_epochs = num_epochs, hidden_layer_sizes=hidden_layer_sizes)
            results = evaluate(test_df, y_pred)
            experiments[embed_model_name][f"pytorch_with_hidden_epochs_{num_epochs}_lr_0.001_per_target_hidden_{'_'.join([str(h) for h in hidden_layer_sizes])}"] = {"model": model, "results": results, "score": results["All Targets"]["F1_score_2class"]}

            model, y_pred = sklearn_MLP_hidden_layers_model_train_predict(train_embed, y_train, test_embed, num_epochs = num_epochs, hidden_layer_sizes=hidden_layer_sizes)
            results = evaluate(test_df, y_pred)
            experiments[embed_model_name][f"sklearn_MLP_with_hidden_epochs_{num_epochs}_lr_0.001_per_target_hidden_{'_'.join([str(h) for h in hidden_layer_sizes])}"] = {"model": model, "results": results, "score": results["All Targets"]["F1_score_2class"]}

# %%
_max = 0
for embed, embed_res in experiments.items():
    for experiment, results in embed_res.items():
        _max = max(_max, results["score"])
        print(f'{embed}\t{experiment}\t{results["score"]}')
_max
# Out:
# paraphrase-multilingual-mpnet-base-v2	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.7071888367908361
# paraphrase-multilingual-mpnet-base-v2	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.7085657144065359
# paraphrase-multilingual-mpnet-base-v2	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.6808949602882461
# paraphrase-multilingual-mpnet-base-v2	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.708503598468126
# paraphrase-multilingual-mpnet-base-v2	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.684792455839366
# paraphrase-multilingual-mpnet-base-v2	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.6953989062634034
# paraphrase-multilingual-mpnet-base-v2	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.6783698333079603
# paraphrase-multilingual-mpnet-base-v2	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.6798945209149209
# paraphrase-multilingual-mpnet-base-v2	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_per_target	0.681773715879968
# paraphrase-multilingual-mpnet-base-v2	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_per_target	0.6973444518218884
# paraphrase-multilingual-mpnet-base-v2	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100	0.6578402593973559
# paraphrase-multilingual-mpnet-base-v2	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100	0.6869905460017193
# paraphrase-multilingual-mpnet-base-v2	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0.6778672439983114
# paraphrase-multilingual-mpnet-base-v2	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0.6898959572822342
# paraphrase-multilingual-mpnet-base-v2	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.6267245190219725
# paraphrase-multilingual-mpnet-base-v2	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.6652641160190522
# paraphrase-multilingual-mpnet-base-v2	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.6808949602882461
# paraphrase-multilingual-mpnet-base-v2	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.708503598468126
# paraphrase-multilingual-mpnet-base-v2	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.6785529209333862
# paraphrase-multilingual-mpnet-base-v2	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.7024669876725299
# paraphrase-multilingual-mpnet-base-v2	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.684792455839366
# paraphrase-multilingual-mpnet-base-v2	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.6953989062634034
# paraphrase-multilingual-mpnet-base-v2	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.6985715643020057
# paraphrase-multilingual-mpnet-base-v2	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.683874536012811
# paraphrase-multilingual-mpnet-base-v2	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.681773715879968
# paraphrase-multilingual-mpnet-base-v2	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.6973444518218884
# paraphrase-multilingual-mpnet-base-v2	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.6578402593973559
# paraphrase-multilingual-mpnet-base-v2	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.6903494552281138
# paraphrase-multilingual-mpnet-base-v2	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.6778672439983114
# paraphrase-multilingual-mpnet-base-v2	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.6898959572822342
# paraphrase-multilingual-mpnet-base-v2	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.6267245190219725
# paraphrase-multilingual-mpnet-base-v2	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.6652641160190522
# qarib_bert-base-qarib_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.7200710310687413
# qarib_bert-base-qarib_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.730504207319772
# qarib_bert-base-qarib_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.7084380394904081
# qarib_bert-base-qarib_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.7147253217189354
# qarib_bert-base-qarib_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.7343877957648005
# qarib_bert-base-qarib_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.7400362766199078
# qarib_bert-base-qarib_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.649901452452902
# qarib_bert-base-qarib_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.7361186026814647
# qarib_bert-base-qarib_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_per_target	0.7210733892025308
# qarib_bert-base-qarib_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_per_target	0.7368281072638592
# qarib_bert-base-qarib_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100	0.6431312313779787
# qarib_bert-base-qarib_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100	0.7229262055943723
# qarib_bert-base-qarib_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0.7305849885464063
# qarib_bert-base-qarib_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0.7262699891976047
# qarib_bert-base-qarib_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.6704328587426321
# qarib_bert-base-qarib_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.7409071780618118
# qarib_bert-base-qarib_avg	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.7200710310687413
# qarib_bert-base-qarib_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.730504207319772
# qarib_bert-base-qarib_avg	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.7084380394904081
# qarib_bert-base-qarib_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.7099957338387378
# qarib_bert-base-qarib_avg	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.7343877957648005
# qarib_bert-base-qarib_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.7400362766199078
# qarib_bert-base-qarib_avg	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.649901452452902
# qarib_bert-base-qarib_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.7413313480860065
# qarib_bert-base-qarib_avg	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.7210733892025308
# qarib_bert-base-qarib_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.7368281072638592
# qarib_bert-base-qarib_avg	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.6431312313779787
# qarib_bert-base-qarib_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.7229262055943723
# qarib_bert-base-qarib_avg	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.7305849885464063
# qarib_bert-base-qarib_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.7262699891976047
# qarib_bert-base-qarib_avg	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.6704328587426321
# qarib_bert-base-qarib_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.7409071780618118
# aubmindlab_bert-base-arabertv02-twitter_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.7389838723504157
# aubmindlab_bert-base-arabertv02-twitter_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.7466160002615049
# aubmindlab_bert-base-arabertv02-twitter_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.7263405004479006
# aubmindlab_bert-base-arabertv02-twitter_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.7209863987767312
# aubmindlab_bert-base-arabertv02-twitter_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.7306202791666948
# aubmindlab_bert-base-arabertv02-twitter_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.7397283716492972
# aubmindlab_bert-base-arabertv02-twitter_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.737858321401155
# aubmindlab_bert-base-arabertv02-twitter_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.7401047752436206
# aubmindlab_bert-base-arabertv02-twitter_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_per_target	0.728908096389083
# aubmindlab_bert-base-arabertv02-twitter_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_per_target	0.7435927434410816
# aubmindlab_bert-base-arabertv02-twitter_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100	0.7178430112437341
# aubmindlab_bert-base-arabertv02-twitter_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100	0.7157392738187106
# aubmindlab_bert-base-arabertv02-twitter_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0.7306595456517847
# aubmindlab_bert-base-arabertv02-twitter_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0.7476567774808297
# aubmindlab_bert-base-arabertv02-twitter_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.6532381027089703
# aubmindlab_bert-base-arabertv02-twitter_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.7252432902886138
# aubmindlab_bert-base-arabertv02-twitter_avg	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.7389838723504157
# aubmindlab_bert-base-arabertv02-twitter_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.7466160002615049
# aubmindlab_bert-base-arabertv02-twitter_avg	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.7355311711645757
# aubmindlab_bert-base-arabertv02-twitter_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.7192782243465455
# aubmindlab_bert-base-arabertv02-twitter_avg	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.7306202791666948
# aubmindlab_bert-base-arabertv02-twitter_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0
v2	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100	0.6394061911713176
# distiluse-base-multilingual-cased-v2	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0.6077639665732303
# distiluse-base-multilingual-cased-v2	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0.6116722912531002
# distiluse-base-multilingual-cased-v2	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.6383055073039147
# distiluse-base-multilingual-cased-v2	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.6335294782033669
# distiluse-base-multilingual-cased-v2	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.6461611477040939
# distiluse-base-multilingual-cased-v2	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.6422250541585051
# distiluse-base-multilingual-cased-v2	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.6301482328685462
# distiluse-base-multilingual-cased-v2	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.6443057533217588
# distiluse-base-multilingual-cased-v2	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.6195291044081367
# distiluse-base-multilingual-cased-v2	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.6237749273255441
# distiluse-base-multilingual-cased-v2	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.6546329347138998
# distiluse-base-multilingual-cased-v2	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.6648331878134118
# distiluse-base-multilingual-cased-v2	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.606555749091378
# distiluse-base-multilingual-cased-v2	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.6130074465071428
# distiluse-base-multilingual-cased-v2	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.6261810385659743
# distiluse-base-multilingual-cased-v2	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.6398245331131459
# distiluse-base-multilingual-cased-v2	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.6077639665732303
# distiluse-base-multilingual-cased-v2	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.6116722912531002
# distiluse-base-multilingual-cased-v2	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.6383055073039147
# distiluse-base-multilingual-cased-v2	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.6114439222058529
# asafaya_bert-base-arabic_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.638167856364585
# asafaya_bert-base-arabic_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.6898385738957117
# asafaya_bert-base-arabic_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.6487858367733986
# asafaya_bert-base-arabic_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.6606198354382168
# asafaya_bert-base-arabic_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.6316324855090878
# asafaya_bert-base-arabic_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.6389655538939107
# asafaya_bert-base-arabic_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.6688488620136179
# asafaya_bert-base-arabic_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.6769592606499715
# asafaya_bert-base-arabic_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_per_target	0.658012903327409
# asafaya_bert-base-arabic_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_per_target	0.6510618724387864
# asafaya_bert-base-arabic_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100	0.5829179123816928
# asafaya_bert-base-arabic_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100	0.6151566579736216
# asafaya_bert-base-arabic_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0.6355382047320446
# asafaya_bert-base-arabic_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0.6637129914915533
# asafaya_bert-base-arabic_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.6632311518114071
# asafaya_bert-base-arabic_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.6077568733055138
# asafaya_bert-base-arabic_cls	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.638167856364585
# asafaya_bert-base-arabic_cls	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.6898385738957117
# asafaya_bert-base-arabic_cls	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.627646113800341
# asafaya_bert-base-arabic_cls	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.6606198354382168
# asafaya_bert-base-arabic_cls	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.6316324855090878
# asafaya_bert-base-arabic_cls	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.6389655538939107
# asafaya_bert-base-arabic_cls	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.676358024691358
# asafaya_bert-base-arabic_cls	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.6769592606499715
# asafaya_bert-base-arabic_cls	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.658012903327409
# asafaya_bert-base-arabic_cls	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.6510618724387864
# asafaya_bert-base-arabic_cls	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.5829179123816928
# asafaya_bert-base-arabic_cls	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.6151566579736216
# asafaya_bert-base-arabic_cls	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.6355382047320446
# asafaya_bert-base-arabic_cls	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.6637129914915533
# asafaya_bert-base-arabic_cls	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.6632311518114071
# asafaya_bert-base-arabic_cls	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.6405788689921531
# asafaya_bert-base-arabic_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.6743726241659919
# asafaya_bert-base-arabic_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.6868488464254625
# asafaya_bert-base-arabic_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.6158056575818804
# asafaya_bert-base-arabic_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.6570567260707004
# asafaya_bert-base-arabic_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.670756600733594
# asafaya_bert-base-arabic_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.7044690222245679
# asafaya_bert-base-arabic_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.6795713796627701
# asafaya_bert-base-arabic_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.6822136953550455
# asafaya_bert-base-arabic_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_per_target	0.6853883761385782
# asafaya_bert-base-arabic_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_per_target	0.7020900686861861
# asafaya_bert-base-arabic_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100	0.5532865737262851
# asafaya_bert-base-arabic_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100	0.6909696401676761
# asafaya_bert-base-arabic_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0
sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0.5114304771624248
# multi-qa-mpnet-base-dot-v1	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.578311721074993
# multi-qa-mpnet-base-dot-v1	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.5879793388158908
# multi-qa-mpnet-base-dot-v1	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.5762010060373236
# multi-qa-mpnet-base-dot-v1	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.5778885742992281
# multi-qa-mpnet-base-dot-v1	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.5743020856775255
# multi-qa-mpnet-base-dot-v1	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.5705500472453889
# multi-qa-mpnet-base-dot-v1	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.5655059052133601
# multi-qa-mpnet-base-dot-v1	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.5287624211537255
# multi-qa-mpnet-base-dot-v1	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.607609173150988
# multi-qa-mpnet-base-dot-v1	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.5421510531703526
# multi-qa-mpnet-base-dot-v1	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.5513423519969762
# multi-qa-mpnet-base-dot-v1	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.5565891484321519
# multi-qa-mpnet-base-dot-v1	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.5372558175425022
# multi-qa-mpnet-base-dot-v1	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.550833535107199
# multi-qa-mpnet-base-dot-v1	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.5229439988175852
# multi-qa-mpnet-base-dot-v1	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.5114304771624248
# multi-qa-mpnet-base-dot-v1	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.5343914123618583
# multi-qa-mpnet-base-dot-v1	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.5879793388158908
# quora-distilbert-multilingual	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.6773810948974438
# quora-distilbert-multilingual	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.6811380475237861
# quora-distilbert-multilingual	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.6769804542803349
# quora-distilbert-multilingual	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.6119198973717274
# quora-distilbert-multilingual	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.6488237902125554
# quora-distilbert-multilingual	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.6392901622991286
# quora-distilbert-multilingual	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.6832688124865157
# quora-distilbert-multilingual	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.6425319339073735
# quora-distilbert-multilingual	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_per_target	0.6573027950973317
# quora-distilbert-multilingual	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_per_target	0.6541597121555444
# quora-distilbert-multilingual	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100	0.6581908633072385
# quora-distilbert-multilingual	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100	0.5423412524336221
# quora-distilbert-multilingual	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0.6493106284872433
# quora-distilbert-multilingual	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0.6223894495863023
# quora-distilbert-multilingual	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.6772872333354085
# quora-distilbert-multilingual	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.6639930586718389
# quora-distilbert-multilingual	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.6773810948974438
# quora-distilbert-multilingual	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.6811380475237861
# quora-distilbert-multilingual	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.6175323044738117
# quora-distilbert-multilingual	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.6119198973717274
# quora-distilbert-multilingual	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.6488237902125554
# quora-distilbert-multilingual	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.6392901622991286
# quora-distilbert-multilingual	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.6219304719498181
# quora-distilbert-multilingual	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.6588264453805707
# quora-distilbert-multilingual	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.6573027950973317
# quora-distilbert-multilingual	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.6541597121555444
# quora-distilbert-multilingual	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.6581908633072385
# quora-distilbert-multilingual	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.5423412524336221
# quora-distilbert-multilingual	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.6493106284872433
# quora-distilbert-multilingual	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.6223894495863023
# quora-distilbert-multilingual	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.5659273413873395
# quora-distilbert-multilingual	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.6639930586718389
# aubmindlab_bert-base-arabertv2_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.6706288721561705
# aubmindlab_bert-base-arabertv2_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.6828263321126081
# aubmindlab_bert-base-arabertv2_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.6853551294338259
# aubmindlab_bert-base-arabertv2_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.6971820699684251
# aubmindlab_bert-base-arabertv2_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.703782306770479
# aubmindlab_bert-base-arabertv2_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.6798245384911078
# aubmindlab_bert-base-arabertv2_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.6948281677235256
# aubmindlab_bert-base-arabertv2_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.6950777121789861
# aubmindlab_bert-base-arabertv2_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_per_target	0.641778346770697
# ...
# aubmindlab_bert-base-arabertv2_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.6978538629668422
# aubmindlab_bert-base-arabertv2_avg	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.7293665585331442
# aubmindlab_bert-base-arabertv2_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.7364789716767848
# aubmindlab_bert-base-arabertv2_avg	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.7418002524602002
# aubmindlab_bert-base-arabertv2_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.7165161386987515
# aubmindlab_bert-base-arabertv2_avg	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.7388999477384116
# aubmindlab_bert-base-arabertv2_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.7491305603577398
# aubmindlab_bert-base-arabertv2_avg	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.6962411294709431
# aubmindlab_bert-base-arabertv2_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.710964436176072
# aubmindlab_bert-base-arabertv2_avg	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.7381825554990021
# aubmindlab_bert-base-arabertv2_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.7499120107123547
# aubmindlab_bert-base-arabertv2_avg	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.6340577366407866
# aubmindlab_bert-base-arabertv2_avg	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.701938191684369
# qarib_bert-base-qarib_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.6787374655308686
# qarib_bert-base-qarib_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.6759762576945132
# qarib_bert-base-qarib_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.6436193996791993
# qarib_bert-base-qarib_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.6290519411158325
# qarib_bert-base-qarib_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.6781090445893408
# qarib_bert-base-qarib_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.7086343237397029
# qarib_bert-base-qarib_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.6650150419316047
# qarib_bert-base-qarib_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.713435852731846
# qarib_bert-base-qarib_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_per_target	0.6705315360776535
# qarib_bert-base-qarib_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_per_target	0.68541367933339
# qarib_bert-base-qarib_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100	0.6221981334494113
# qarib_bert-base-qarib_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100	0.6568642169465052
# qarib_bert-base-qarib_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0.6657433919638772
# qarib_bert-base-qarib_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0.6802354337773592
# qarib_bert-base-qarib_cls	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.5989540415968215
# qarib_bert-base-qarib_cls	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.669610508830215
# qarib_bert-base-qarib_cls	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.6787374655308686
# qarib_bert-base-qarib_cls	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.6759762576945132
# qarib_bert-base-qarib_cls	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.6290672269943641
# qarib_bert-base-qarib_cls	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.6803185592404045
# qarib_bert-base-qarib_cls	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.6781090445893408
# qarib_bert-base-qarib_cls	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.7086343237397029
# qarib_bert-base-qarib_cls	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.6121107357187533
# qarib_bert-base-qarib_cls	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.713435852731846
# qarib_bert-base-qarib_cls	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.6705315360776535
# qarib_bert-base-qarib_cls	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.68541367933339
# qarib_bert-base-qarib_cls	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.6221981334494113
# qarib_bert-base-qarib_cls	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.6568642169465052
# qarib_bert-base-qarib_cls	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.6657433919638772
# qarib_bert-base-qarib_cls	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.6802354337773592
# qarib_bert-base-qarib_cls	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.5989540415968215
# qarib_bert-base-qarib_cls	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.669610508830215
# LaBSE	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.667454195491537
# LaBSE	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.673384882116836
# LaBSE	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.6702650451423814
# LaBSE	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100	0.6703085521477159
# LaBSE	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.6609269424234947
# LaBSE	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_per_target	0.6837649434601522
# LaBSE	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.6859714177534691
# LaBSE	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300	0.6983475736703979
# LaBSE	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_per_target	0.675437383431698
# LaBSE	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_per_target	0.6799523336409333
# LaBSE	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100	0.6634073944349069
# LaBSE	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100	0.6594698443280321
# LaBSE	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0.6751264107721533
# LaBSE	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10_per_target	0.6539511208167025
# LaBSE	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.6776961206130613
# LaBSE	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_300_100_10	0.6518986424869738
# LaBSE	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.667454195491537
# LaBSE	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100_per_target	0.673384882116836
# LaBSE	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.6528768521013103
# LaBSE	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_100	0.6776440353768289
# LaBSE	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.6609269424234947
# LaBSE	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_per_target	0.6837649434601522
# LaBSE	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.6862177791130888
# LaBSE	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300	0.6877831213694591
# LaBSE	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.675437383431698
# LaBSE	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_per_target	0.6799523336409333
# LaBSE	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.6601420375710986
# LaBSE	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100	0.654708334172989
# LaBSE	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.6751264107721533
# LaBSE	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10_per_target	0.6539511208167025
# LaBSE	pytorch_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.6876748572420102
# LaBSE	sklearn_MLP_with_hidden_epochs_1000_lr_0.001_per_target_hidden_300_100_10	0.6518986424869738
# UBC-NLP_ARBERT_avg	pytorch_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0.6985113793746986
# UBC-NLP_ARBERT_avg	sklearn_MLP_with_hidden_epochs_100_lr_0.001_per_target_hidden_100_per_target	0